# %% [markdown]
# # Chapter 5 - Outlier Analysis
# ## Segment 8 - Extreme value analysis using univariate methods

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4

# %%
address = 'D:/GoogleDrive/WGU/C996-Programming in Python/jupyter_notebook/Python for Data Science Essential Training Part 1/Data/iris.data.csv'
df = pd.read_csv(filepath_or_buffer=address, header=None, sep=',')

df.columns=['Sepal Length','Sepal Width','Petal Length','Petal Width', 'Species']
df.head(10)
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
#df = data frame
#data slicing to select first 4 coulumns
#data split into x and y variables
x = df.iloc[:,0:4].values

y = df.iloc[:,4].values

# #print first 5 records
df[:5]
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0      5.100000     3.500000      1.400000     0.200000  setosa
# 1      4.900000     3.000000      1.400000     0.200000  setosa
# 2      4.700000     3.200000      1.300000     0.200000  setosa
# 3      4.600000     3.100000      1.500000     0.200000  setosa
# 4      5.000000     3.600000      1.400000     0.200000  setosa

# %% [markdown]
# ### Identifying outliers from Tukey boxplots

# %%
df.boxplot(return_type='dict')
plt.plot()
# Out:
# []

# %%
#Select the column Sepal Width
Sepal_width = x[:,1]
iris_outliers = (Sepal_width > 4)
#filter data frame outliers
df[iris_outliers]
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 15           5.7          4.4           1.5          0.4  setosa
# 32           5.2          4.1           1.5          0.1  setosa
# 33           5.5          4.2           1.4          0.2  setosa

# %%
Sepal_width = x[:,1]
iris_outliers = (Sepal_width < 2.05)
#filter data frame outliers
df[iris_outliers]
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width     Species
# 60           5.0          2.0           3.5          1.0  versicolor

# %% [markdown]
# ### Applying Tukey outlier labeling

# %%
pd.options.display.float_format = '{:1f}'.format
X_df = pd.DataFrame(x)
X_df.describe()
# Out:
#                0          1          2          3
# count 150.000000 150.000000 150.000000 150.000000
# mean    5.843333   3.057333   3.758000   1.199333
# std     0.828066   0.435866   1.765298   0.762238
# min     4.300000   2.000000   1.000000   0.100000
# 25%     5.100000   2.800000   1.600000   0.300000
# 50%     5.800000   3.000000   4.350000   1.300000
# 75%     6.400000   3.300000   5.100000   1.800000
# max     7.900000   4.400000   6.900000   2.500000
