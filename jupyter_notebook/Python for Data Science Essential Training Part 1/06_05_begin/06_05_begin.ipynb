# %% [markdown]
# # Chapter 6 -  Data Sourcing via Web
# ## Segment 5 - Introduction to NLP

# %%
import nltk

# %%
text = "On Wednesday, the Association for Computing Machinery, the world’s largest society of computing professionals, announced that Hinton, LeCun and Bengio had won this year’s Turing Award for their work on neural networks. The Turing Award, which was introduced in 1966, is often called the Nobel Prize of computing, and it includes a $1 million prize, which the three scientists will share."

# %%
#Bring sentence tokenizer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dayan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# <h3>Sentence Tokenizer</h3>

# %%
from nltk.tokenize import sent_tokenize
sent_tk = sent_tokenize(text)
print("Sentence tokenizing the text: \n")
print(sent_tk)
# Out:
# Sentence tokenizing the text:
#
# ['On Wednesday, the Association for Computing Machinery, the world’s largest society of computing professionals, announced that Hinton, LeCun and Bengio had won this year’s Turing Award for their work on neural networks.', 'The Turing Award, which was introduced in 1966, is often called the Nobel Prize of computing, and it includes a $1 million prize, which the three scientists will share.']

# %% [markdown]
# ### Word Tokenizer

# %%
from nltk.tokenize import word_tokenize
word_tk = word_tokenize(text)
word_tk = [c.lower() for c in word_tk] 
print(type(word_tk))
print("Word tokenizing the text: \n")
print(word_tk)
# Out:
# <class 'list'>
# Word tokenizing the text:
#
# ['on', 'wednesday', ',', 'the', 'association', 'for', 'computing', 'machinery', ',', 'the', 'world', '’', 's', 'largest', 'society', 'of', 'computing', 'professionals', ',', 'announced', 'that', 'hinton', ',', 'lecun', 'and', 'bengio', 'had', 'won', 'this', 'year', '’', 's', 'turing', 'award', 'for', 'their', 'work', 'on', 'neural', 'networks', '.', 'the', 'turing', 'award', ',', 'which', 'was', 'introduced', 'in', '1966', ',', 'is', 'often', 'called', 'the', 'nobel', 'prize', 'of', 'computing', ',', 'and', 'it', 'includes', 'a', '$', '1', 'million', 'prize', ',', 'which', 'the', 'three', 'scientists', 'will', 'share', '.']

# %% [markdown]
# ### Removing stop words

# %%
nltk.download('stopwords')

# %%
from nltk.corpus import stopwords
sw = set(stopwords.words("english"))
sw.update([',','.',])
print(len(sw))
print(type(sw))
print("Stop words in English language are: \n")
print(sw)
# Out:
# 181
# <class 'set'>
# Stop words in English language are:
#
# {'wasn', 'while', 'am', "doesn't", 'too', 'her', 'few', 'above', "you'll", 'were', 'm', 'more', 'only', "hadn't", 'than', 't', 'through', 'any', 'other', ',', 'herself', 'further', "aren't", 'an', 'she', 'won', "should've", "wasn't", 'doing', 'again', 'some', 'can', 'do', 'and', 'a', 'each', 'mustn', 'myself', "you'd", 'we', 'be', "you're", 'him', 'out', "mightn't", 'when', 'over', 'on', 'after', 'd', 'the', "hasn't", 'if', 'not', "you've", 'that', 'during', 'same', 'isn', 'own', 'ma', 'is', "it's", 'yourselves', 'below', 'there', 's', 'aren', 'their', 'where', 'just', 'haven', 'needn', 'very', 'me', 'then', 'he', 'weren', 'wouldn', 'couldn', "weren't", 'will', 'don', 'for', 'i', 'off', "couldn't", 'shan', 're', 'who', 'until', 'before', 'down', 'yours', 'by', 'does', 'ours', 'its', 'having', 've', 'of', 'once', "she's", 'because', 'with', "won't", 'which', 'between', "haven't", 'ain', 'll', 'your', 'was', 'as', 'up', 'what', 'whom', 'in', 'hers', '.', "shan't", 'y', 'these', 'have', "isn't", 'most', 'themselves', 'has', 'why', 'had', "shouldn't", 'are', 'no', 'to', 'our', 'or', 'against', 'been', 'his', "needn't", 'how', 'itself', 'didn', 'doesn', 'yourself', 'my', 'shouldn', 'hasn', 'you', 'ourselves', 'theirs', 'at', 'both', 'mightn', "wouldn't", 'it', 'into', 'should', 'o', "that'll", 'did', 'from', 'nor', 'about', 'such', 'this', "didn't", 'under', 'but', 'hadn', 'so', 'now', 'himself', 'them', "don't", 'those', 'they', 'all', "mustn't", 'here', 'being'}

# %%
#filter
filtered_words = [w for w in word_tk if not w in sw]
print("Text after removing stop words: \n")
print(filtered_words)
# Out:
# Text after removing stop words:
#
# ['wednesday', 'association', 'computing', 'machinery', 'world', '’', 'largest', 'society', 'computing', 'professionals', 'announced', 'hinton', 'lecun', 'bengio', 'year', '’', 'turing', 'award', 'work', 'neural', 'networks', 'turing', 'award', 'introduced', '1966', 'often', 'called', 'nobel', 'prize', 'computing', 'includes', '$', '1', 'million', 'prize', 'three', 'scientists', 'share']

# %% [markdown]
# <h3>Stemming</h3>

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
port_stem = PorterStemmer()

# %%
stemmed_words = []
for w in filtered_words:
    stemmed_words.append(port_stem.stem(w))

print("Filtered Sentence: \n", filtered_words, "\n")
print("Stemmed Sentence: \n", stemmed_words)
# Out:
# Filtered Sentence:
#  ['wednesday', 'association', 'computing', 'machinery', 'world', '’', 'largest', 'society', 'computing', 'professionals', 'announced', 'hinton', 'lecun', 'bengio', 'year', '’', 'turing', 'award', 'work', 'neural', 'networks', 'turing', 'award', 'introduced', '1966', 'often', 'called', 'nobel', 'prize', 'computing', 'includes', '$', '1', 'million', 'prize', 'three', 'scientists', 'share']
#
# Stemmed Sentence:
#  ['wednesday', 'associ', 'comput', 'machineri', 'world', '’', 'largest', 'societi', 'comput', 'profession', 'announc', 'hinton', 'lecun', 'bengio', 'year', '’', 'ture', 'award', 'work', 'neural', 'network', 'ture', 'award', 'introduc', '1966', 'often', 'call', 'nobel', 'prize', 'comput', 'includ', '$', '1', 'million', 'prize', 'three', 'scientist', 'share']

# %% [markdown]
# ## Lemmatizing

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dayan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

lemm_words = []
for i in range(len(filtered_words)):
    lemm_words.append(lem.lemmatize(filtered_words[i]))
print(lemm_words)
# Out:
# ['wednesday', 'association', 'computing', 'machinery', 'world', '’', 'largest', 'society', 'computing', 'professional', 'announced', 'hinton', 'lecun', 'bengio', 'year', '’', 'turing', 'award', 'work', 'neural', 'network', 'turing', 'award', 'introduced', '1966', 'often', 'called', 'nobel', 'prize', 'computing', 'includes', '$', '1', 'million', 'prize', 'three', 'scientist', 'share']

# %% [markdown]
# ### Parts of Speech Tagging

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dayan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
from nltk import pos_tag
pos_tagged_words = pos_tag(word_tk)

print(pos_tagged_words)
# Out:
# [('On', 'IN'), ('Wednesday', 'NNP'), (',', ','), ('the', 'DT'), ('Association', 'NNP'), ('for', 'IN'), ('Computing', 'VBG'), ('Machinery', 'NNP'), (',', ','), ('the', 'DT'), ('world', 'NN'), ('’', 'NNP'), ('s', 'RB'), ('largest', 'JJS'), ('society', 'NN'), ('of', 'IN'), ('computing', 'VBG'), ('professionals', 'NNS'), (',', ','), ('announced', 'VBD'), ('that', 'IN'), ('Hinton', 'NNP'), (',', ','), ('LeCun', 'NNP'), ('and', 'CC'), ('Bengio', 'NNP'), ('had', 'VBD'), ('won', 'VBN'), ('this', 'DT'), ('year', 'NN'), ('’', 'VBZ'), ('s', 'JJ'), ('Turing', 'NNP'), ('Award', 'NNP'), ('for', 'IN'), ('their', 'PRP$'), ('work', 'NN'), ('on', 'IN'), ('neural', 'JJ'), ('networks', 'NNS'), ('.', '.'), ('The', 'DT'), ('Turing', 'NNP'), ('Award', 'NNP'), (',', ','), ('which', 'WDT'), ('was', 'VBD'), ('introduced', 'VBN'), ('in', 'IN'), ('1966', 'CD'), (',', ','), ('is', 'VBZ'), ('often', 'RB'), ('called', 'VBN'), ('the', 'DT'), ('Nobel', 'NNP'), ('Prize', 'NNP'), ('of', 'IN'), ('computing', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('includes', 'VBZ'), ('a', 'DT'), ('$', '$'), ('1', 'CD'), ('million', 'CD'), ('prize', 'NN'), (',', ','), ('which', 'WDT'), ('the', 'DT'), ('three', 'CD'), ('scientists', 'NNS'), ('will', 'MD'), ('share', 'NN'), ('.', '.')]

# %% [markdown]
# ### Frequency Distribution Plots

# %%
from nltk.probability import FreqDist
fd = FreqDist(word_tk)

print(fd)
# Out:
# <FreqDist with 52 samples and 76 outcomes>

# %%
import matplotlib.pyplot as plt
fd.plot(10, cumulative=True)
plt.show()

# %%
fd_alpha = FreqDist(text)
fd_alpha.plot(30, cumulative=False)
plt.show()

# %%
fd_beta = FreqDist(lemm_words)
fd_beta.plot(30, cumulative=False)
plt.show()
